# %% [markdown]
# # <center>**Phase I: Exploratory Data Analysis**

# %%
import os
os.getcwd()
os.chdir('E:/DSP')

# %% [markdown]
# ## **Importing Libraries**

# %%
# importing necessary modules
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Loading Data**

# %%
pd.set_option('display.max_columns', None)

# %%
df_train = pd.read_csv('study_materials/LearnML/house-prices-advanced-regression-techniques/train.csv')
df_test = pd.read_csv('study_materials/LearnML/house-prices-advanced-regression-techniques/test.csv')

# %%
df_train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %% [markdown]
# ## **Gathering Basic Info**

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
"""
LotFrontage - Interpolate 
Alley - 'No alley access'
MasVnrType - 'None'
MasVnrArea - Interpolate
BsmtQual - 'No basement'
BsmtCond - 'No basement'
BsmtExposure - 'No basement'
BsmtFinType1 - 'No basement'
BsmtFinType2 - 'No basement'
Electrical - Decide
FireplaceQu - Depends on Fireplaces (if 0, then 'No fireplace')
GarageType - 'No garage'
GarageYrBlt - '0'
GarageFinish - 'No garage'
GarageQual - 'No garage'
GarageCond - 'No garage'
PoolQC - Depends on PoolArea (if 0, then 'No pool')
Fence - 'No fence'
MiscFeature - 'No extras'
"""
# Out:
# "\nLotFrontage - Interpolate \nAlley - 'No alley access'\nMasVnrType - 'None'\nMasVnrArea - Interpolate\nBsmtQual - 'No basement'\nBsmtCond - 'No basement'\nBsmtExposure - 'No basement'\nBsmtFinType1 - 'No basement'\nBsmtFinType2 - 'No basement'\nElectrical - Decide\nFireplaceQu - Depends on Fireplaces (if 0, then 'No fireplace')\nGarageType - 'No garage'\nGarageYrBlt - '0'\nGarageFinish - 'No garage'\nGarageQual - 'No garage'\nGarageCond - 'No garage'\nPoolQC - Depends on PoolArea (if 0, then 'No pool')\nFence - 'No fence'\nMiscFeature - 'No extras'\n"

# %%
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
num_cols = ['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
            'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 
            'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', 
            '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 
            'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 
            'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 
            'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
            'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 
            'MiscVal', 'YrSold', 'SalePrice']

# %%
cat_cols = ['MSSubClass', 'MSZoning', 'Street', 'Alley',
            'LotShape', 'LandContour', 'Utilities', 'LotConfig',
            'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
            'BldgType', 'HouseStyle','RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
            'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 
            'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
            'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 
            'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu',
            'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 
            'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 
            'MoSold', 'SaleType', 'SaleCondition']

# %%
nom_cat_cols = ['MSSubClass', 'MSZoning', 'Street', 'Alley',
            'LotShape', 'LandContour', 'Utilities', 'LotConfig',
            'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
            'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 
            'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 
            'Heating', 'CentralAir', 'Electrical', 'GarageType', 
            'GarageFinish', 'PavedDrive', 'Fence', 'MiscFeature', 
            'MoSold', 'SaleType', 'SaleCondition']

ord_cat_cols = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 
                'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 
                'KitchenQual', 'Functional', 'FireplaceQu', 'GarageQual', 
                'GarageCond', 'PoolQC']

# %% [markdown]
# ## **Filling Missing Values**

# %%
# Replacing null values by the replacements
cat_replacements = {
    'Alley': 'No alley access',
    'MasVnrType': 'None',
    'BsmtQual': 'No basement',
    'BsmtCond': 'No basement',
    'BsmtExposure': 'No basement',
    'BsmtFinType1': 'No basement',
    'BsmtFinType2': 'No basement',
    'GarageType': 'No garage',
    'GarageFinish': 'No garage',
    'GarageQual': 'No garage',
    'GarageCond': 'No garage',
    'Fence': 'No fence',
    'MiscFeature': 'No extras'
}
df_train.fillna(value=cat_replacements, inplace=True)

df_train['GarageYrBlt'].fillna(0, inplace=True)

df_train['LotFrontage'] = df_train.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))
# Fill any remaining gaps (e.g., if a neighborhood has no LotFrontage data) with the overall median
df_train['LotFrontage'] = df_train['LotFrontage'].fillna(df_train['LotFrontage'].median())

df_train['MasVnrArea'] = df_train['MasVnrArea'].fillna(df_train['MasVnrArea'].median())

# %%
# FireplaceQu: If Fireplaces == 0, fill with 'No fireplace'
df_train.loc[(df_train['FireplaceQu'].isnull()) & (df_train['Fireplaces'] == 0), 'FireplaceQu'] = 'No fireplace'
# Catch-all just in case there are remaining nulls where Fireplaces > 0
df_train['FireplaceQu'].fillna('No fireplace', inplace=True)

# PoolQC: If PoolArea == 0, fill with 'No pool'
df_train.loc[(df_train['PoolQC'].isnull()) & (df_train['PoolArea'] == 0), 'PoolQC'] = 'No pool'
df_train['PoolQC'].fillna('No pool', inplace=True)

# Filling with the mode (most frequent value) of the column
electrical_mode = df_train['Electrical'].mode()[0]
df_train['Electrical'].fillna(electrical_mode, inplace=True)

# %%
# Verification
remaining_nulls = df_train[num_cols + cat_cols].isnull().sum()
print("Remaining null values per column:")
print(remaining_nulls[remaining_nulls > 0])
# Out:
# Remaining null values per column:
# Series([], dtype: int64)

# %% [markdown]
# ## **Univariate Analysis**

# %%
# Set style for clean aesthetics
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["axes.titleweight"] = "bold"

# %%
# Target Variable Distribution
sns.histplot(df_train['SalePrice'], kde=True, color='blue')

plt.show()

# %% [markdown]
# * From the histogram above, we can see that most houses are priced between 70K USD and 400K USD.
# * Since the distribution of the target variable (`SalePrice`) is right-skewed, we apply log transformation to make the distribution normal.

# %%
# House prices are right-skewed; checking if log-transform make the distribution normal
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(df_train['SalePrice'], kde=True, ax=axes[0], color='blue')
axes[0].set_title('Original SalePrice Distribution')

sns.histplot(np.log(df_train['SalePrice']), kde=True, ax=axes[1], color='green')
axes[1].set_title('Log-Transformed SalePrice Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# --> Target variable is log-transformed.

# %%
# LotFrontage and LotArea Distribution
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(df_train['LotFrontage'], kde=True, ax=axes[0], color='cyan')
axes[0].set_title('LotFrontage Distribution')
axes[0].set_xlabel('LotFrontage (in ft)')

sns.histplot(df_train['LotArea'], kde=True, ax=axes[1], color='red')
axes[1].set_title('LotArea Distribution')
axes[1].set_xlabel('LotArea (in sqft)')


plt.tight_layout()
plt.show()

# %% [markdown]
# * From the histograms above, we can see that most houses have a front length measuring roughly from 25ft to 125ft of the street.
# * The lot area of the houses are normally within 25000sqft with few exceptions that largely exceed this value.

# %%
# Houses sold over the years
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

ax1 = axes[0, 0]
ax2 = axes[0, 1]

axes[1, 0].remove()
axes[1, 1].remove()
ax3 = fig.add_subplot(2, 1, 2)

# 1. Yearly Sales Volume
p1 = sns.countplot(data=df_train, x='YrSold', ax=ax1, palette='Blues_d')
ax1.set_title('Number of Houses Sold Per Year')
ax1.set_xlabel('Year Sold')
ax1.set_ylabel('Count of Sales')

for container in p1.containers:
    p1.bar_label(container)

# 2. Monthly Distribution broken down by Year
sns.countplot(data=df_train, x='MoSold', hue='YrSold', ax=ax2, palette='tab10')
ax2.set_title('Monthly Sales Distribution Across Years')
ax2.set_xlabel('Month Sold')
ax2.set_ylabel('Count of Sales')
ax2.legend(title='Year')

# 3. Average Houses Sold per Month (True Seasonality)
# Group by both Year and Month to get counts, then average those counts by Month
monthly_counts = df_train.groupby(['YrSold', 'MoSold']).size().reset_index(name='SalesCount')
avg_monthly_sales = monthly_counts.groupby('MoSold')['SalesCount'].mean().reset_index()

p2 = sns.barplot(data=avg_monthly_sales, x='MoSold', y='SalesCount', ax=ax3, palette='coolwarm')
ax3.set_title('Average Number of Houses Sold per Month')
ax3.set_xlabel('Month Sold')
ax3.set_ylabel('Average Sales Count')

for container in p2.containers:
    p2.bar_label(container)

plt.tight_layout()

# %% [markdown]
# * There is an evident decline in the houses sold in the year 2010, right from the 7th month July.
# * From 2006 to 2009, the sales have been consistent throughout with June being the month having most sales.
# * Due to the sudden decline of sales in 2010 from August, the average number of houses sold shows a declination, however, those months still have a decent number of houses being sold due to the presence of consistent sales in the previous years.

# %%
# Quality of the houses and Sale condition
fig = plt.subplots(2, 2, figsize=(18, 14))

# 4. OverallQual and OverallCond (Distribution/Count Check)
ax1 = plt.subplot(2, 2, 1)
sns.countplot(data=df_train, x='OverallQual', ax=ax1, palette='legendary' if 'legendary' in plt.colormaps() else 'Blues')
ax1.set_title('Distribution of Overall Quality Ratings (1-10)')
ax1.set_xlabel('Overall Quality')

for container in ax1.containers:
    ax1.bar_label(container)

ax2 = plt.subplot(2, 2, 2)
sns.countplot(data=df_train, x='OverallCond', ax=ax2, palette='coolwarm')
ax2.set_title('Distribution of Overall Condition Ratings (1-10)')
ax2.set_xlabel('Overall Condition')

for container in ax2.containers:
    ax2.bar_label(container)

# 5. YearBuilt and YearRemodAdd Comparison
ax3 = plt.subplot(2, 2, 3)
sns.kdeplot(data=df_train['YearBuilt'], fill=True, label='Year Built', ax=ax3, color='blue', alpha=0.4)
sns.kdeplot(data=df_train['YearRemodAdd'], fill=True, label='Year Remodeled', ax=ax3, color='orange', alpha=0.4)
#sns.kdeplot(data=df_train['YrSold'], fill=True, label='Year Sold', ax=ax3, color='green', alpha=0.4)
ax3.set_title('Timeline Comparison: Year Built vs. Year Remodeled')
ax3.set_xlabel('Year')
ax3.set_ylabel('Density')
ax3.legend()

# 6. SaleCondition Pie Chart
ax4 = plt.subplot(2, 2, 4)
sale_cond_counts = df_train['SaleCondition'].value_counts()
ax4.pie(sale_cond_counts, labels=sale_cond_counts.index, autopct='%1.1f%%', 
        startangle=90, colors=sns.color_palette('pastel'), explode=[0.05 if i==0 else 0 for i in range(len(sale_cond_counts))])
ax4.set_title('Proportion of Sale Conditions')
ax4.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# * Overall quality refer to the material and finishing of the houses. A big proportion of the houses are scored 5 and above with most houses being average (rated 5).
# * Though the finishing of the houses are rated higher, the condition of about more than 800 houses are average (rated 5).
# * Houses are being built from after 1850 with a peaks and downfall seen in the graph. Between 1925 and 1950, houses seem to start remodel. However, the data entries the year built value for houses that were not remodeled. Due to that, we see a significant peak in Year Remodel, higher than the peak correspondingly seen around the 2000s.
# * 82 percent of the sales are normal and 8.6 percent of the sales are partial, meaning that the house was not completed (for new homes).

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 14))

# 7. Ground Living Area
ax1 = plt.subplot(2, 2, 1)
sns.histplot(df_train['GrLivArea'], kde=True, ax=ax1, color='purple')
ax1.set_title('Distribution of Ground Living Area (SqFt)')
ax1.set_xlabel('GrLivArea')

# 8. First Floor Square Footage
ax2 = plt.subplot(2, 2, 2)
sns.histplot(df_train['1stFlrSF'], kde=True, ax=ax2, color='teal')
ax2.set_title('Distribution of 1st Floor Area (SqFt)')
ax2.set_xlabel('1stFlrSF')

# 9. Second Floor Square Footage
# houses_with_2ndflr = df_train[df_train['2ndFlrSF']>0]
ax3 = plt.subplot(2, 2, 3)
sns.histplot(df_train['2ndFlrSF'], kde=True, ax=ax3, color='green')
ax3.set_title('Distribution of 2nd Floor Area (SqFt)')
ax3.set_xlabel('2ndFlrSF')

# 10. Total Basement Square Footage
# houses_with_base = df_train[df_train['TotalBsmtSF']>0]
ax4 = plt.subplot(2, 2, 4)
sns.histplot(df_train['TotalBsmtSF'], kde=True, ax=ax4, color='crimson')
ax4.set_title('Distribution of Total Basement Area (SqFt)')
ax4.set_xlabel('TotalBsmtSF')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Comparing the areas of ground living and first floor, there is a very slight similarity in their distribution with a reduction in the first floor area since ground generally covers more portion than the subsequent floors.
# * There are spikes at 0 in both the bottom part histograms of the graph which is due to the absence of the features: 2nd floor and basement, respectively. Considering only the houses having such features, the 2nd floor area distribution might look normal while that of the basement will have a positive skewness due to the data points observing a large basement area.

# %% [markdown]
# ## **Bivariate Analysis**

# %%
# Relationship of SalePrice with few other variables
fig = plt.figure(figsize=(18, 30))
gs = fig.add_gridspec(5, 2)

ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])

ax3 = fig.add_subplot(gs[1, 0])
ax4 = fig.add_subplot(gs[1, 1])

ax5 = fig.add_subplot(gs[2, :])

ax6 = fig.add_subplot(gs[3, 0])
ax7 = fig.add_subplot(gs[3, 1])

ax8 = fig.add_subplot(gs[4, :])

# 1. Ground Living Area vs SalePrice
sns.scatterplot(data=df_train, x='GrLivArea', y='SalePrice', alpha=0.4, ax=ax1, color='purple')
ax1.set_title('Ground Living Area (GrLivArea) vs SalePrice')
ax1.set_xlabel('Above Grade Living Area (SqFt)')
ax1.set_ylabel('Sale Price ($)')

# 2. Total Basement Square Footage vs SalePrice
sns.scatterplot(data=df_train, x='TotalBsmtSF', y='SalePrice', alpha=0.4, ax=ax2, color='teal')
ax2.set_title('Total Basement Area (TotalBsmtSF) vs SalePrice')
ax2.set_xlabel('Total Basement Area (SqFt)')
ax2.set_ylabel('Sale Price ($)')

# 3. LotArea vs SalePrice
sns.scatterplot(data=df_train, x='LotArea', y='SalePrice', alpha=0.4, ax=ax3, color='brown')
#ax3.set_xscale('log')
ax3.set_title('Lot Area (LotArea) vs SalePrice')
ax3.set_xlabel('Lot Area (SqFt)')
ax3.set_ylabel('Sale Price ($)')

# 4. LotArea < 50000 vs SalePrice
sns.scatterplot(data=df_train[df_train['LotArea']<50000], 
                x='LotArea', y='SalePrice', alpha=0.4, ax=ax4, color='brown')
ax4.set_title('Lot Area (LotArea < 50000) vs SalePrice')
ax4.set_xlabel('Lot Area (SqFt)')
ax4.set_ylabel('Sale Price ($)')

# 5. Log of LotArea vs SalePrice
sns.scatterplot(data=pd.concat([np.log(df_train[['LotArea']]), df_train[['SalePrice']]],axis=1), 
                x='LotArea', y='SalePrice', alpha=0.4, ax=ax5, color='brown')
ax5.set_title('Log of LotArea (LotArea) vs SalePrice')
ax5.set_xlabel('Log Lot Area (SqFt)')
ax5.set_ylabel('Sale Price ($)')

# 6. OverallQual vs SalePrice
#sns.boxplot(data=df_train, x='OverallQual', y='SalePrice', ax=ax6, color='coral')
sns.violinplot(data=df_train, x="OverallQual", y="SalePrice", bw_adjust=.5, inner="box", inner_kws=dict(box_width=5, whis_width=1, color="red"), ax=ax6, palette='Blues')
ax6.set_title('Overall Quality (OverallQual) vs SalePrice')
ax6.set_xlabel('Overall Quality (rating 1-10)')
ax6.set_ylabel('Sale Price ($)')

#sns.scatterplot(data=df_train, x='OverallCond', y='SalePrice', alpha=0.5, ax=ax7, color='coral')
#ax7.set_title('Overall Condition (OverallCond) vs SalePrice')
#ax7.set_xlabel('Overall Condition (rating 1-10)')
#ax7.set_ylabel('Sale Price ($)')

# 7. OverallCond vs SalePrice
sns.violinplot(data=df_train, x="OverallCond", y="SalePrice", bw_adjust=.5, inner="box", inner_kws=dict(box_width=5, whis_width=1, color="red"), ax=ax7, palette='Blues')
#sns.boxplot(data=df_train, x='OverallCond', y='SalePrice', ax=ax7, color='coral')
ax7.set_title('Overall Condition (OverallCond) vs SalePrice')
ax7.set_xlabel('Overall Condition (rating 1-10)')
ax7.set_ylabel('Sale Price ($)')

# 8. SaleCondition vs SalePrice
sns.boxplot(data=df_train, x='SaleCondition', y='SalePrice', ax=ax8, color='gold')
ax8.set_title('Impact of Sale Conditon on Sale Price')
ax8.set_xlabel('Sale Condition')
ax8.set_ylabel('Sale Price ($)')

plt.tight_layout()
plt.show()

# %% [markdown]
# * **Ground Living Area (GrLivArea) vs SalePrice**
#
# The plot shows a linear relationship between these two variables and a clutter of points is seen around x=1000sqft implying the similarity of prices. It can also be observed that there are certain outliers depicted by the points past the 4000sqft ground living area and above 600K USD sale price.The latter outliers can be kept but the former ones need to be inspected.
# * **Total Basement Area (TotalBsmtSF) vs SalePrice**
#
# Similar to the previous plot, there is a linear relationship seen here as well with outliers beyond 3000sqft total basement area (need to be inspected) and above 600K USD sale price. However, there are few points seen lying along zero. This could potentially mean that those houses do not have a basement.
# * **Lot Area (LotArea) vs SalePrice & Log Lot Area (LotArea < 50000) vs SalePrice**
#
# Unlike the plots seen so far, this is a different one due to the presence of a lot of outliers identified by points lying past the 100000sqft and most importantly the relationship between the variables does not seem to be linear. By filtering out the data and looking at the same scatterplot for houses with less than 50000sqft, we could still see a lot of outliers with more area and less price.
# * **Log of LotArea (LotArea) vs SalePrice**
#
# Plotting the same but with `LotArea` being log-transformed, we find that the relationship is not exactly linear and the outliers didn't seem to be diminished by this transformation.
# * **Overall Quality (OverallQual) vs SalePrice**
#
# The overall quality vs sale price plot shows growth in sale prices as ratings increases. Outliers are also seen as 7-rated and 8-rated houses are sold at lower prices and it should be noted that 10-rated houses have been sold at a low price.
# * **Overall Condition (OverallCond) vs SalePrice**
#
# Though the overall quality shows a positive increase in sale prices, it is quite the opposite in this plot. Distinctively, there are no 10-rated houses but only one 1-rated house in the dataset. A definite outlier noticed here is 2-rated houses sold at a massive higher price. In the 5-rated and 6-rated category, there are houses sold for prices between 700K USD - 800K USD, which is higher than the maximum price of a 9-rated house. A lot of the well-conditioned houses are sold at prices lower than the average ones.
#
# * **Impact of Sale Conditon on Final Transaction Price**
#
# Most properties sold under normal sale conditions are concentrated between 100K USD and 200K USD. Abnormal sales, such as foreclosures and short sales, generally have lower sale prices and rarely exceed 350K USD – 400K USD, apart from a single extreme outlier which could either be a 5-rated or 6-rated house. On the other hand, properties with a 'Partial' sale condition tend to be much more expensive, with prices reaching close to 600K USD. This is likely because many of these properties are newly constructed homes. Allocation sales also appear to be on the lower end of the price range, with most properties selling below 300K USD.

# %%
# Neighborhood stats
neigh_stats = df_train.groupby('Neighborhood')['SalePrice'].agg(['mean', 'size']).reset_index()
neigh_stats_sorted = neigh_stats.sort_values(by='mean')

fig, axes = plt.subplots(2, 1, figsize=(16, 14))

# Average SalePrice across neighborhoods
sns.barplot(data=neigh_stats_sorted, x='Neighborhood', y='mean', ax=axes[0], palette='crest')
axes[0].set_title('Average Sale Price Across Neighborhoods')
axes[0].set_ylabel('Average Price ($)')
axes[0].tick_params(axis='x', rotation=45)

# Data points per Neighborhood
p3 = sns.barplot(data=neigh_stats_sorted, x='Neighborhood', y='size', ax=axes[1], linewidth=1, edgecolor='0.5', color='lightblue')
axes[1].set_title('Number of Records Available per Neighborhood')
axes[1].set_ylabel('Record Count')
#axes[1].axhline(30, color='red', linestyle='--', label='Minimum Safe Sample Size Threshold (30)')
axes[1].legend()
axes[1].tick_params(axis='x', rotation=45)

for container in p3.containers:
    p3.bar_label(container)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Plot 1:**
# From the first plot, one can easily see the following:
#
# **Neighborhoods with High Average Sale Price (Top 3)**
# * `NoRidge` (Northridge)
# * `Nridght` (Northridge Heights)
# * `StoneBr` (Stone Brook)
#
# **Neighborhoods with Low Avergae Sale Price (Bottom 3)**
# * `MeadowV` (Meadow Village)
# * `IDOTRR` (Iowa DOT and Rail Road)
# * `BrDale` (Briardale)
#
# **Plot 2:**
# From the second plot, it can be seen that `Veenker` (Veenker), the fifth neighborhood to have highest average sale price has only 11 records which is not sufficient enough to capture the prices in that neighborhood. This observation also occurs in neighborhoods such as `Blueste` (Bluestem), `NPkVill` (Northpark Villa), even `StoneBr` (Stone Brook). A look at the price distribution is needed for each neighborhood.

# %%
# SalePrice distribution across neighborhoods
g = sns.FacetGrid(df_train, col="Neighborhood", col_wrap=5, height=3, sharex=False, palette='muted')
g.map_dataframe(sns.histplot, x="SalePrice", kde=True, color="teal", bins=15)

g.set_titles(col_template="{col_name}")
g.set_axis_labels("Sale Price ($)", "Count")
plt.subplots_adjust(hspace=0.4, wspace=0.3)

plt.show()

# %% [markdown]
# Clearly, there are several plateaued plots observed in the figure indicating very less data points which are not enough to depict the average price in those neighborhoods.

# %% [markdown]
# ## **Multivariate Analysis**

# %%
# Correlation Heatmap
num_cols = ['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
            'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 
            'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', 
            '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 
            'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 
            'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 
            'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
            'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 
            'MiscVal', 'YrSold', 'SalePrice']

plt.figure(figsize=(20, 15))
corr_matrix = df_train[num_cols].corr()

sns.heatmap(corr_matrix, annot=True, annot_kws={'size':8}, cmap='vlag', fmt=".2f", linewidths=0.5, square=True)
plt.title('Correlation Matrix of Numerical Features with SalePrice')
plt.show()

# %% [markdown]
# **Top strongly positive correlated factors with target**
# * `OverallQual` (0.79)
# * `GrLivArea` (0.71)
# * `GarageCars` (0.64)
# * `GarageArea` (0.62)
# * `TotalBsmtSF` (0.61)
# * `1stFLrSF` (0.61)
#
# **Top moderately positive correlated factors with target**
# * `FullBath` (0.56)
# * `TotRmsAbvGrd` (0.53)
# * `YearBuilt` (0.52)
# * `YearRemodAdd` (0.51)
#
# **Features with high correlation**
# * `TotRmsAbvGrd` and `GrLivArea` (0.83)
# * `GarageArea` and `GarageCars` (0.83)
# * `1stFlrSF` and `TotalBsmtSF` (0.82)
#
# **Features with moderate correlation**
# * `GrLivArea` and `2ndFlrSF` (0.69)
# * `TotRmsAbvGrd` and `BedroomAbvGr` (0.68)
# * `BsmtFullBath` and `BsmtFinSF1` (0.65)
# * `FullBath` and `GrLivArea` (0.63)
# * `TotRmsAbvGrd` and `2ndFlrSF` (0.62)
# * `HalfBath` and `2ndFlrSF` (0.61)

# %% [markdown]
# **Summary**
#
# In the top strongly positive correlated features with target, the pairs `GarageCars`, `GarageArea` and `TotalBsmtSF`, `1stFlrSF` have similar correlation coefficients as expected. More interestingly, the feature `FullBath` denoting the number of full bathrooms in a house have a positive correlation with the `SalePrice`, followed by `TotRmsAbvGrd` (Total rooms above grade or ground). Along with the top features having a linear relationship with the target, it is identified that there is a strong correlation within features itself. A prominent one that can be caught without even finding the correlation coefficient is the `GarageCars` and `GarageArea`; obviously `1stFlrSF` and `TotalBsmtSF` also have high correlation due to similar measurements in some houses.

# %%
# Pairplot of some variables for reference
plt.figure()

sns.pairplot(df_train[['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 
                       'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 
                       'YearBuilt', 'YearRemodAdd', 'SalePrice']],
            diag_kind='kde', plot_kws={'alpha': 0.5, 'color': 'purple'})
plt.suptitle('Pairplot of strongly correlated features with SalePrice', fontsize=12, fontweight='bold', y=1.02)
plt.show()

# %%
# Pairplot of highly correlated variables for reference
plt.figure()

sns.pairplot(df_train[['TotRmsAbvGrd', 'GrLivArea',
                       'GarageCars', 'GarageArea',
                       '1stFlrSF', 'TotalBsmtSF']],
            diag_kind='kde', plot_kws={'alpha': 0.5, 'color': 'purple'})
plt.suptitle('Pairplot of highly correlated features', fontsize=12, fontweight='bold', y=1.02)
plt.show()
